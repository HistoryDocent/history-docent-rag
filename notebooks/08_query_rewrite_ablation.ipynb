# %% [markdown]
# # 08 Query Rewrite Ablation
#
# ## 목적
# place-aware query rewrite가 짧고 모호한 관광/음성형 질문에 도움이 되는지 검증한다.
#
# ## 비교군
# - Hybrid
# - Hybrid + place catalog
# - Hybrid + query rewrite
# - Hybrid + place catalog + query rewrite
#
# ## 통과 기준
# invalid rewrite JSON 0, voice_followup 개선, place_relevance 개선.
