# %% [markdown]
# # 11 RAPTOR Lite Experiment
#
# ## 목적
# RAPTOR-lite가 overview, place_story, route_context 질문에 도움이 되는지 검증한다.
#
# ## 원칙
# - summary node는 검색 힌트로만 사용한다.
# - 최종 citation은 원문 child/parent chunk만 사용한다.
# - summary 자체를 근거로 쓰지 않는다.
#
# ## 성공 기준
# overview 유형 Correct-with-Evidence +3%p 이상, citation_precision 하락 없음.
