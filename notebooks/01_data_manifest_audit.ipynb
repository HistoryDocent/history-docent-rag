# %% [markdown]
# # 01 Data Manifest Audit
#
# ## 목적
# 12개 원본 문서와 parser 결과가 `data_manifest`에 누락 없이 등록됐는지 검증한다.
#
# ## 정량 지표
# - document_missing_count
# - duplicate_doc_id_count
# - missing_pdf_path_count
# - missing_parser_output_count
# - private_path_leakage_count
#
# ## 안전 규칙
# public sample에는 private absolute path를 출력하지 않는다.
