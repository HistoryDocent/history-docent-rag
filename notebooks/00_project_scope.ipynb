# %% [markdown]
# # 00 Project Scope
#
# ## 목적
# 서울/한양 관광 도슨트 RAG 백엔드의 MVP 범위, non-goal, 평가 기준을 확인한다.
#
# ## 확인 항목
# - 제품 문제 정의
# - 대상 사용자
# - MVP 기능
# - 제외 기능
# - 평가 gate
#
# ## 안전 규칙
# 원본 PDF, 전체 parser JSON, 전체 chunk text, API key를 출력하지 않는다.
