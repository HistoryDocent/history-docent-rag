# %% [markdown]
# # 02 Parser Quality Check
#
# ## 목적
# Upstage Parser 결과의 품질을 문서별로 집계한다.
#
# ## 정량 지표
# - parser_page_count
# - empty_page_count
# - heading_missing_rate
# - ocr_noise_block_count
# - base64_removed_count
# - summary_error_artifact_count
#
# ## 정성 검수
# 표지, 목차, 장 시작, 본문, 표/그림 포함 페이지를 redacted sample로 검수한다.
