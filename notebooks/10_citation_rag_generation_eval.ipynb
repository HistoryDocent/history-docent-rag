# %% [markdown]
# # 10 Citation RAG Generation Eval
#
# ## 목적
# citation RAG 답변의 correctness, faithfulness, citation 품질, spoken_answer 품질을 평가한다.
#
# ## 정량 지표
# - Correct-with-Evidence
# - citation_precision
# - citation_recall
# - place_relevance
# - unsupported_claim_rate
# - abstention_accuracy
#
# ## 정성 검수
# 현장 관광객이 30초 안에 이해할 수 있는지 확인한다.
