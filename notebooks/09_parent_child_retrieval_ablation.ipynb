# %% [markdown]
# # 09 Parent Child Retrieval Ablation
#
# ## 목적
# child-only retrieval과 parent-child context expansion의 차이를 검증한다.
#
# ## 비교군
# - child-only
# - parent-child
# - parent-child + compression
# - parent-child + reranker
#
# ## 판단 기준
# Evidence Recall@5, citation precision, latency_p95를 함께 본다.
