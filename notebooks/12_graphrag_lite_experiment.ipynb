# %% [markdown]
# # 12 GraphRAG Lite Experiment
#
# ## 목적
# GraphRAG-lite가 relationship 질문에 도움이 되는지 검증한다.
#
# ## 원칙
# - graph triple은 근거가 아니다.
# - graph는 retrieval hint다.
# - 최종 citation은 원문 chunk다.
#
# ## 성공 기준
# relationship 유형 Correct-with-Evidence +3%p 이상, entity resolution 오류율 5% 이하.
