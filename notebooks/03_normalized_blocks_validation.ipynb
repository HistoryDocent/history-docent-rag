# %% [markdown]
# # 03 Normalized Blocks Validation
#
# ## 목적
# `normalized_blocks.jsonl` schema와 provenance를 검증한다.
#
# ## 정량 지표
# - required_field_null_count
# - page_global_reverse_count
# - duplicate_block_id_count
# - empty_text_block_count
# - unknown_element_type_count
#
# ## 통과 기준
# 필수 field null 0, page_global 역전 0, duplicate block_id 0.
