# %% [markdown]
# # 13 Final Ablation Report
#
# ## 목적
# 전체 ablation 결과를 포트폴리오용 최종 판단으로 정리한다.
#
# ## 포함 항목
# - BM25/Dense/Hybrid 비교
# - Query Rewrite 효과
# - Parent-Child 효과
# - Citation RAG 생성 품질
# - RAPTOR-lite 결과
# - GraphRAG-lite 결과
# - 최종 선택 근거
#
# ## 개선 주장 규칙
# 95% confidence interval이 0을 지나면 개선을 주장하지 않는다.
